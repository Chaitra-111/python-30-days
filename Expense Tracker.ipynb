# %%
import pandas as pd
import os

FILE = "expenses.csv"

# Create file if not exists
if not os.path.exists(FILE):
    df = pd.DataFrame(columns=["Date", "Category", "Amount", "Note"])
    df.to_csv(FILE, index=False)

def add_expense():
    date = input("Enter date (YYYY-MM-DD): ")
    category = input("Enter category (Food, Travel, etc): ")
    amount = float(input("Enter amount: "))
    note = input("Enter note: ")

    new_data = pd.DataFrame([[date, category, amount, note]],
                            columns=["Date", "Category", "Amount", "Note"])

    new_data.to_csv(FILE, mode='a', header=False, index=False)
    print("✅ Expense added successfully!")

# %%
def view_expenses():
    df = pd.read_csv(FILE)
    print("\n📋 All Expenses:\n")
    print(df)

# %%
def category_summary():
    df = pd.read_csv(FILE)
    summary = df.groupby("Category")["Amount"].sum()
    
    print("\n📊 Category-wise Summary:\n")
    print(summary)

# %%
import matplotlib.pyplot as plt

def show_graph():
    df = pd.read_csv(FILE)
    
    summary = df.groupby("Category")["Amount"].sum()

    summary.plot(kind='bar')
    plt.title("Expenses by Category")
    plt.xlabel("Category")
    plt.ylabel("Amount")
    plt.show()

# %%
##### def main():
    while True:
        print("\n==== Expense Tracker ====")
        print("1. Add Expense")
        print("2. View Expenses")
        print("3. Category Summary")
        print("4. Show Graph")
        print("5. Exit")

        choice = input("Enter choice: ")

        if choice == '1':
            add_expense()
        elif choice == '2':
            view_expenses()
        elif choice == '3':
            category_summary()
        elif choice == '4':
            show_graph()
        elif choice == '5':
            print("👋 Exiting...")
            break
        else:
            print("❌ Invalid choice")

if __name__ == "__main__":
    main()
# Out:
# ==== Expense Tracker ====
# 1. Add Expense
# 2. View Expenses
# 3. Category Summary
# 4. Show Graph
# 5. Exit
# Enter choice:  1
# Enter date (YYYY-MM-DD):  2004-12-21
# Enter category (Food, Travel, etc):  travel
# Enter amount:  25000
# Enter note:  kedarnath
# ✅ Expense added successfully!
#
# ==== Expense Tracker ====
# 1. Add Expense
# 2. View Expenses
# 3. Category Summary
# 4. Show Graph
# 5. Exit
# Enter choice:  2
# 📋 All Expenses:
#
#          Date Category   Amount       Note
# 0  2004-12-21   travel  25000.0  kedarnath
#
# ==== Expense Tracker ====
# 1. Add Expense
# 2. View Expenses
# 3. Category Summary
# 4. Show Graph
# 5. Exit
# Enter choice:  1
# Enter date (YYYY-MM-DD):  2027-03-03
# Enter category (Food, Travel, etc):  food
# Enter amount:  2000
# Enter note:  chicken
# ✅ Expense added successfully!
#
# ==== Expense Tracker ====
# 1. Add Expense
# 2. View Expenses
# 3. Category Summary
# 4. Show Graph
# 5. Exit
# Enter choice:  1
# Enter date (YYYY-MM-DD):  1991-08-28
# Enter category (Food, Travel, etc):  painting
# Enter amount:  6000
# Enter note:  krishna painting
# ✅ Expense added successfully!
#
# ==== Expense Tracker ====
# 1. Add Expense
# 2. View Expenses
# 3. Category Summary
# 4. Show Graph
# 5. Exit
# Enter choice:  3
# 📊 Category-wise Summary:
#
# Category
# food         2000.0
# painting     6000.0
# travel      25000.0
# Name: Amount, dtype: float64
#
# ==== Expense Tracker ====
# 1. Add Expense
# 2. View Expenses
# 3. Category Summary
# 4. Show Graph
# 5. Exit
# Enter choice:  4
# ==== Expense Tracker ====
# 1. Add Expense
# 2. View Expenses
# 3. Category Summary
# 4. Show Graph
# 5. Exit
# Enter choice:  5
# 👋 Exiting...
