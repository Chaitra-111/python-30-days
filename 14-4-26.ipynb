# %% [markdown]
# # MEDIUM

# %%
#1
string="Python"
print(string[::-1])
# Out:
# nohtyP

# %%
#2
list1=['Hello','World']
' '.join(list1)
# Out:
# 'Hello World'

# %%
#3
flt=3.14159
print(f'{flt:.2f}')
# Out:
# 3.14

# %%
#4
s = "abcdefgh"
print(s[::2])
# Out:
# aceg

# %%
#5
str1='banana'
print(str1.count('na'))
# Out:
# 2

# %%
#6
str1='Hello World'
str1.startswith('Hello')
# Out:
# True

# %%
#7
str2='the quick brown fox'
str2.title()
# Out:
# 'The Quick Brown Fox'

# %%
#8
str3='Python'
str3[1:4]
# Out:
# 'yth'

# %%
#9
print(f'{7:03}')
# Out:
# 007

# %%
#10
import re
words='one two three'
ex=re.findall(f"[\w.]+[\s]+[\w.]+[\s]+\w+",words)
print(ex)
# Out:
# ['one two three']

# %% [markdown]
# # HARD

# %%
#1
str1 = input()
clean = str1.replace(" ", "").lower()

if clean == clean[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
#  maDam
# Palindrome

# %%
#2
str5 = "hello world"
cap = [i.capitalize() for i in str5.split()]
print(" ".join(cap))
# Out:
# Hello World

# %%
#3
sub=re.sub(r'\d+','#',"the numbers are 143 and 987")
print(sub)
# Out:
# the numbers are # and #

# %%
#4
text = "cafe"
enc = text.encode()
dec = enc.decode()
print(enc)
print(dec)
# Out:
# b'cafe'
# cafe

# %%
#5
s = "hello"
print(s.find("x")) #it shows -1 if not found

print(s.index("x")) #ValueError if not found
# Out:
# -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 5
#       2 s = "hello"
#       3 print(s.find("x")) #it shows -1 if not found
# ----> 5 print(s.index("x")) #ValueError if not found
#
# ValueError: substring not found

# %%
#6
word = "mississippi"
D = {}
for i in word:
    if i in D:
        D[i]= D[i]+1
    else:
        D[i] = 1
print(D)
# Out:
# {'m': 1, 'i': 4, 's': 4, 'p': 2}

# %%
#7
bool(re.fullmatch(r'\d{10}',"7995531535"))
# Out:
# True

# %%
#8---string cant be changed
s = "hello"
s2 = s + " world"
print("before replace: ",s)
s.replace('hello','hey') #we cant replace or modify the string,it provides same as before
print('after replace: ',s)
print(s2)
# Out:
# before replace:  hello
# after replace:  hello
# hello world

# %%
#9
text = "this is chaitra and this is from datateach".split()
freq = {}
for i in text:
    freq[i] = freq.get(i, 0) + 1
print(freq)
# Out:
# {'this': 2, 'is': 2, 'chaitra': 1, 'and': 1, 'from': 1, 'datateach': 1}

# %%
#10
print('name=Alice'.partition('='))
# Out:
# ('name', '=', 'Alice')
